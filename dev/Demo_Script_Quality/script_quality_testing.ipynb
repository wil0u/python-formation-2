# %% [markdown]
# # Script Quality

# %% [markdown]
# ### Test script_quality_not_ok.py

# %%
! pycodestyle script_quality_not_ok.py
# Out:
# script_quality_not_ok.py:7:30: E231 missing whitespace after ','
# script_quality_not_ok.py:7:38: E202 whitespace before ')'
# script_quality_not_ok.py:27:21: E225 missing whitespace around operator
# script_quality_not_ok.py:31:50: E231 missing whitespace after ','
# script_quality_not_ok.py:32:10: E211 whitespace before '('
# script_quality_not_ok.py:32:10: E271 multiple spaces after keyword

# %% [markdown]
# ### script_quality_ok.py

# %%
! pycodestyle script_quality_ok.py
