# %% [markdown]
# # OBJET EN MEMOIRE ET OCCUPATION DE LA MEMOIRE

# %%
# deux variables différentes qui pointent sur la meme donnée
var1 = 5
var2 = 5
var3 = 5.0
var4 =var1

# %%
# Affiche l'adresse mémoire de localisation de la donnée
# python variables sont des pointeurs
print(hex(id(var1)))
print(hex(id(var2)))
print(hex(id(var3)))
print(hex(id(var4)))
# Out:
# 0x55a0ce6f0300
# 0x55a0ce6f0300
# 0x7f8c33417130
# 0x55a0ce6f0300

# %%
# c'est la meme adresse

# %%
# si on modifie la valeur, l'emplacement change

# %%
var1 = var1**2

# %%
print(hex(id(var1)))
print(hex(id(var2)))
print(hex(id(var3)))
print(hex(id(var4)))
# Out:
# 0x55a0ce6f0580
# 0x55a0ce6f0300
# 0x7f8c33417130
# 0x55a0ce6f0300

# %% [markdown]
# OCCUPATION MEMOIRE

# %%
import psutil

# %%
print(psutil.virtual_memory())
# Out:
# svmem(total=8415277056, available=4356927488, percent=48.2, used=4058349568, free=4356927488)

# %%
# Big vecteur numérique de 500 M 
import numpy as np
x=np.random.rand(500000000)

# %%
print(psutil.virtual_memory())
# Out:
# svmem(total=8415277056, available=840626176, percent=90.0, used=7574650880, free=840626176)

# %%
del x

# %%
print(psutil.virtual_memory())
# Out:
# svmem(total=8415277056, available=6043688960, percent=28.2, used=2371588096, free=6043688960)
