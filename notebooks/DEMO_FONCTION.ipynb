# %%
# création d'une fonction qui renvoie le carré de x
def fonc_carre(x):
    return x**2

# %%
fonc_carre(5)
# Out:
# 25

# %%
# Si l'utilisateur utilise mal la fonction, on a une erreur
fonc_carre('5')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-12-35b14077821f> in <module>
#       1 # Si l'utilisateur utilise mal la fonciton
# ----> 2 fonc_carre('5')
#
# <ipython-input-10-3f2f20d32d53> in fonc_carre(x)
#       1 # création d'une fonction qui renvoie le carré de x
#       2 def fonc_carre(x):
# ----> 3     return x**2
#
# TypeError: unsupported operand type(s) for ** or pow(): 'str' and 'int'

# %%
# On va donc attraper cette erreur pour programmer un comportement face à cette erreur
def fonc_carre(x):
    try:
        return x**2
    except TypeError:
        print("x n'est pas un nombre!!!")

# %%
fonc_carre('5')
# Out:
# x n'est pas un nombre!!!

# %%
fonc_carre(2)
# Out:
# 4
