# %%
import os
os.getcwd()
# Out:
# '/home/jupyter/EF-form-py-data'

# %%
os.chdir('/home/jupyter/EF-form-py-data/data')
list=os.listdir()

# %%
list
# Out:
# ['exemple.json',
#  '.ipynb_checkpoints',
#  'exercice_RH',
#  'housingdata.csv',
#  'irisHTTP.csv',
#  'iris.json',
#  'don.pydata',
#  'churn.csv',
#  'don.csv',
#  'green_tripdata_2018-01.hdf5']

# %%
'fichier.json'.find('csv')
# Out:
# -1

# %%
# Retenir que les fichiers qui contenaient csv
liste_csv=[]
for i in list:
    print(i)
    if i.find('csv')>0:
        print("csv")
        liste_csv.append(i)
# Out:
# exemple.json
# .ipynb_checkpoints
# exercice_RH
# housingdata.csv
# csv
# irisHTTP.csv
# csv
# iris.json
# don.pydata
# churn.csv
# csv
# don.csv
# csv
# green_tripdata_2018-01.hdf5

# %%
liste_csv
# Out:
# ['housingdata.csv', 'irisHTTP.csv', 'churn.csv', 'don.csv']
