# %%
# Import librairie
import configparser

# %%
# Lecture du fichier de config
config_file = 'config_2.ini'
config = configparser.ConfigParser()
config.read(config_file)
# Out:
# ['config_2.ini']

# %%
# Accès aux différents éléments
print(config['GCP']['path'])
print(config['GCP']['project_id'])
# Out:
# dsfr-frxxx-frxxxdev.EPSILON_DEV
# dsfr-frxxx-frxxx-dev

# %%
# Exemple d'utilisation
tablename = "{dataset}.{table}".format(dataset=config['GCP']['path'], table=config['DATASET']['user'])
tablename
# Out:
# 'dsfr-frxxx-frxxxdev.EPSILON_DEV.epsilon_perimetre_user_recommandation'
