# %%
# Import des librairies
import json

# %%
# Chemin des paramètres stockés dans un json
credential_path = 'exemple_connection_database.json'

# %%
# Lecture du json et stockage dans un objet de type dictionnaire
with open(credential_path) as f:
    params = json.load(f)

# %%
# Affichage du dictionnaire
params
# Out:
# {'database': 'mimosa',
#  'host': 'xxx.softbda.corp',
#  'login': 'dgr',
#  'mdp': 'xxxx'}

# %%
# Accès à un paramètre
params['database']
# Out:
# 'mimosa'
