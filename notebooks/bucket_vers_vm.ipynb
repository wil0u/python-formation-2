# %%
from google.cloud import storage
import pandas as pd
import sys
from io import StringIO

client=storage.Client()
bucket=client.get_bucket("epsi-tech-dsc-formation-202005")
df_string=bucket.get_blob("data/people.csv").download_as_string()

#filename =  "C:/Users/dgr/Documents/data/green_tripdata_2018-01.csv"

# %%
from io import BytesIO
from io import BytesIO
df=pd.read_csv(BytesIO(df_string),encoding='UTF-8',sep=',')
df.to_csv("people.csv",encoding='UTF-8',sep=',',index=False)
