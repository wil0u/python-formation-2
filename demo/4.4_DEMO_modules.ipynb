# %% [markdown]
# ### Il est nécessaire d'installer le package operations basique via la commande pip install -e "chemin\vers\le\dossier\contenant\setup.py"
# ### Ensuite il faut restart le notebook

# %%
import operations_basique.arithmetic as ar

# %%
ar.add(1,2)
# Out:
# 3

# %%
ar.multiply(3,4)
# Out:
# 12

# %%
ar.subtract(5,3)
# Out:
# 2

# %%
ar.divide(10,0)
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 ar.divide(10,0)
#
# File ~\python-formation-2\operations_basique\src\operations_basique\arithmetic.py:21, in divide(a, b)
#      19 """Return the quotient of *a* and *b*, raising on division by zero."""
#      20 if b == 0:
# ---> 21     raise ZeroDivisionError("Cannot divide by zero")
#      22 return a / b
#
# ZeroDivisionError: Cannot divide by zero
